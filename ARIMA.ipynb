# %%
import pandas as pd
from pandas import datetime
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.preprocessing.sequence import TimeseriesGenerator
from keras.models import Sequential
from keras.layers import Dense
from ke
# Out:
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
fd = pd.read_excel('fd.xlsx',index_col=0)

# %%
fd
# Out:
#                                                 Carriageway_Start_Name  \
# Road_Name
# Access Road #2                                                     NaN
# Kirkbride Road                                              Westney Rd
# COATESVILLE RIVERHEAD HIGHWAY                           RIVERHEAD ROAD
# COATESVILLE RIVERHEAD HIGHWAY                         STATE HIGHWAY 17
# Bader Drive                                                        NaN
# Bader Drive                                                        NaN
# Buckland Road                                                      NaN
# Buckland Road                                                      NaN
# Buckland Road                                         Allen St Mangere
# Kirkbride Road                                Mckenzie Rd Kirkbride Rd
# Massey Road                                              Buckland Road
# Massey Road                                               Imrie Avenue
# ...

# %%
fd1=fd[['Count_Start_Date','Monday_Volume','Tuesday_Volume','Wednesday_Volume','Thursday_Volume','Wednesday_Volume','Thursday_Volume','Friday_Volume','Saturday_Volume','Sunday_Volume']]

# %%
fd1.set_index('Count_Start_Date')
# Out:
#                   Monday_Volume  Tuesday_Volume  Wednesday_Volume  \
# Count_Start_Date
# 2012-05-25          1573.818182     1442.666667       1923.555556
# 2012-07-15         15758.545455    14445.333333      19260.444444
# 2012-07-16          4825.090909     4423.000000       5897.333333
# 2012-07-16          5563.636364     5100.000000       6800.000000
# 2012-07-16         15511.454545    14218.833333      18958.444444
# 2012-07-16         21207.272727    19440.000000      25920.000000
# 2012-07-16          9348.909091     8569.833333      11426.444444
# 2012-07-16          8222.909091     7537.666667      10050.222222
# 2012-07-16          9506.545455     8714.333333      11619.111111
# 2012-07-16          9267.818182     8495.500000      11327.333333
# 2012-07-16         17600.909091    16134.166667      21512.222222
# 2012-07-16         21258.727273    19487.166667      25982.888889
# 2012-07-16         20052.727273    18381.666667      24508.888889
# ...

# %%
fd1.values.shape
# Out:
# (12431, 10)

# %%
train,test=fd[6000:8000],fd[8000:10000]

# %%
scaler=MinMaxScaler()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-76320f52de90> in <module>()
# ----> 1 scaler=MinMaxScaler()
#
# NameError: name 'MinMaxScaler' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-025ebd141efa> in <module>()
#       1 t_columns=['Count_Start_Date','Monday_Volume','Tuesday_Volume','Wednesday_Volume','Thursday_Volume','Friday_Volume','Saturday_Volume','Sunday_Volume']
#       2 t_transformer=RobustScaler()
# ----> 3 t_transformer=t_transformer.fit(train[t_columns].to_numpy())
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'to_numpy'
