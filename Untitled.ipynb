# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_excel('traffic-counts-to-august-2019 (Autosaved).xlsx')

# %%
df.head()
# Out:
#     Area                      Road_Name Carriageway_Start_Name  \
# 0  North                 Access Road #2                    NaN
# 1  South                 Kirkbride Road             Westney Rd
# 2  North  COATESVILLE RIVERHEAD HIGHWAY         RIVERHEAD ROAD
# 3  North  COATESVILLE RIVERHEAD HIGHWAY       STATE HIGHWAY 17
# 4  South                    Bader Drive                    NaN
#
#         Carriageway_End_Name  \
# 0                        NaN
# 1  End 750 Massey Rd Moble S
# 2           STATE HIGHWAY 16
# 3               WIDTH CHANGE
# 4                        NaN
#
#                                          Description Direction  \
# 0                                    At Bridge 1020m      Both
# 1  !Kirkbride Rd ((Approx 80m east Westney Rd - o...      Both
# 2                 Coatsville-Riverhead Highway 80kph      Both
# 3                         C-R H'way 50m S SH17 80kph      Both
# 4  !Bader Dr (Approx 150 east Bader Dr off-ramp o...      Both
#
# ...

# %%
df.tail()
# Out:
#       Area                          Road_Name Carriageway_Start_Name  \
# 12426  NaN          PAKURANGA RD (EAST BOUND)          TAMAKI BAY DR
# 12427  NaN          PAKURANGA RD (EAST BOUND)            TI RAKAU DR
# 12428  NaN  EAST COAST RD (SILVERDALE_REDVALE                SPUR RD
# 12429  NaN              GREEN RD 2 (MATAKANA)           WIDTH CHANGE
# 12430  NaN                    WILKS RD (EAST)          ALPURT BRIDGE
#
#                            Carriageway_End_Name         Description Direction  \
# 12426                               TI RAKAU DR  E1766358  N5913252      Both
# 12427  END OF DIVIDED CARRIAGEWAY - ISLAND NOSE  E1766559  N5913299      Both
# 12428                           WILKS RD (EAST)  E1749187  N5942726      Both
# 12429                                 LYSNAR RD  E1754163  N5971952      Both
# 12430                             EAST COAST RD  E1749131  N5942633      Both
#
#       Count_Start_Date  5_Day_ADT    7_Day_ADT  Saturday_Volume     ...       \
# ...

# %% [markdown]
# # Data Types

# %%
df.dtypes
# Out:
# Area                              object
# Road_Name                         object
# Carriageway_Start_Name            object
# Carriageway_End_Name              object
# Description                       object
# Direction                         object
# Count_Start_Date          datetime64[ns]
# 5_Day_ADT                        float64
# 7_Day_ADT                        float64
# Saturday_Volume                  float64
# Sunday_Volume                    float64
# AM_Peak_Volume                   float64
# AM_Peak_Hour                     float64
# Mid_Peak_Volume                  float64
# Mid_Peak_Hour                    float64
# PM_Peak_Volume                   float64
# PM_Peak_Hour                     float64
# Car                              float64
# LCV                              float64
# MCV                              float64
# HCV-I                            float64
# HCV-II                           float64
# HCV Total                        float64
# ...

# %%
df['Road_Name'] = df.Road_Name.astype(str)

# %%
df.dtypes
# Out:
# Area                              object
# Road_Name                         object
# Carriageway_Start_Name            object
# Carriageway_End_Name              object
# Description                       object
# Direction                         object
# Count_Start_Date          datetime64[ns]
# 5_Day_ADT                        float64
# 7_Day_ADT                        float64
# Saturday_Volume                  float64
# Sunday_Volume                    float64
# AM_Peak_Volume                   float64
# AM_Peak_Hour                     float64
# Mid_Peak_Volume                  float64
# Mid_Peak_Hour                    float64
# PM_Peak_Volume                   float64
# PM_Peak_Hour                     float64
# Car                              float64
# LCV                              float64
# MCV                              float64
# HCV-I                            float64
# HCV-II                           float64
# HCV Total                        float64
# ...

# %%
trainY=df['Car'][:20]
trainx=df['Count_Start_Date'][:20]
testY=df['Car'][20:40]
testX=df['Count_Start_Date'][20:40]

# %%
plt.plot(trainx, trainY, color='g')
plt.xlabel('Date')
plt.ylabel('Percentage Of Cars')
plt.title('Traffic in the Morning')
plt.show()
