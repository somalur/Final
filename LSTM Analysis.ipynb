# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
sns.set()
# %matplotlib inline

# %%
df = pd.read_excel("traffic-counts-to-august-2019 (Autosaved).xlsx")

# %%
df.shape
# Out:
# (12431, 29)

# %%
df.isnull().values.any()
# Out:
# True

# %%
df = df.dropna()

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.head(10)
# Out:
#      Area                      Road_Name    Carriageway_Start_Name  \
# 1   South                 Kirkbride Road                Westney Rd
# 2   North  COATESVILLE RIVERHEAD HIGHWAY            RIVERHEAD ROAD
# 3   North  COATESVILLE RIVERHEAD HIGHWAY          STATE HIGHWAY 17
# 8   South                  Buckland Road          Allen St Mangere
# 9   South                 Kirkbride Road  Mckenzie Rd Kirkbride Rd
# 10  South                    Massey Road             Buckland Road
# 11  South                    Massey Road              Imrie Avenue
# 12  South                    Massey Road          Tennessee Avenue
# 13  South                    Massey Road     Plumley Crescent East
# 14  South                  Mckenzie Road     Walmsley Rd-Miller Rd
#
#          Carriageway_End_Name  \
# 1   End 750 Massey Rd Moble S
# 2            STATE HIGHWAY 16
# 3                WIDTH CHANGE
# 8                 Massey Road
# 9                Idlewild Ave
# 10              Walter Street
# 11             Friesian Drive
# 12               Viola Avenue
# 13                Thomas Road
# 14              Coronation Rd
#
#                                           Description Direction  \
# 1   !Kirkbride Rd ((Approx 80m east Westney Rd - o...      Both
# 2                  Coatsville-Riverhead Highway 80kph      Both
# 3                          C-R H'way 50m S SH17 80kph      Both
# 8   !Buckland Rd (Approx 50m north Allen St outsid...      Both
# 9   !Kirkbride Rd (Approx 60 north of Idlewild Ave...      Both
# 10  !Massey Rd (Approx 40m west Walter St outside ...      Both
# 11  !Massey Rd (Approx 15m east Tussock Ave outsid...      Both
# 12  !Massey Rd (Approx 120m east of Viola Ave outs...      Both
# 13  !Massey Rd (Approx 100m east Thomas Rd outside...      Both
# 14  !McKenzie Rd (Approx 170m north Walmsley Rd ou...      Both
#
#    Count_Start_Date  Five_Day_ADT  Seven_Day_ADT  Saturday_Volume  \
# 1        2012-07-15       17334.4   15659.857143          12921.0
# 2        2012-07-16        5307.6    5230.857143           5999.0
# 3        2012-07-16        6120.0    5820.571429           5962.0
# 8        2012-07-16       10457.2   10347.714286          11936.0
# 9        2012-07-16       10194.6    8924.142857           6769.0
# 10       2012-07-16       19361.0   18349.857143          18471.0
# 11       2012-07-16       23384.6   21713.142857          20804.0
# 12       2012-07-16       22058.0   20923.857143          21566.0
# 13       2012-07-16       17831.4   16429.142857          15093.0
# 14       2012-07-16       14234.6   13256.285714          12935.0
#
#              ...                  MCV     HCV-I    HCV-II  HCV Total  \
# 1            ...             0.043076  0.008812  0.003941   0.055830
# 2            ...             0.026518  0.012290  0.003468   0.042277
# 3            ...             0.029010  0.012615  0.003264   0.044890
# 8            ...             0.016056  0.003327  0.000621   0.020004
# 9            ...             0.089084  0.016744  0.012438   0.118267
# 10           ...             0.024850  0.012285  0.006501   0.043636
# 11           ...             0.031173  0.008599  0.003744   0.043515
# 12           ...             0.030833  0.005605  0.002403   0.038842
# 13           ...             0.032947  0.008165  0.006069   0.047181
# 14           ...             0.029388  0.015066  0.009052   0.053506
#
#     AM-Non-Peak-Hours  AM-Non-Peak-Hour-Volume  Mid-Day-Non-Peak-Hour-Time  \
# 1                0901                    141.0                      1244.0
# 2                0902                    111.0                      1245.0
# 3                0903                    146.0                      1231.0
# 8                0908                    117.0                      1232.0
# 9                0909                    125.0                      1241.0
# 10               0910                     96.0                      1244.0
# 11               0911                     94.0                      1237.0
# 12               0912                    144.0                      1236.0
# 13               0913                    160.0                      1234.0
# 14               0914                    105.0                      1238.0
#
#     Mid-Day-Non-Peak-Volume  PM-Non-Peak-Hours  PM-Non-Peak-Hour-Volume
# 1                       136             1626.0                    152.0
# 2                       142             1619.0                    197.0
# 3                       165             1623.0                    195.0
# 8                       116             1627.0                    121.0
# 9                       170             1623.0                    117.0
# 10                      151             1630.0                    171.0
# 11                      188             1628.0                    155.0
# 12                      113             1616.0                    165.0
# 13                      181             1623.0                    127.0
# 14                      195             1622.0                    140.0
#
# [10 rows x 29 columns]
